# %%
# Data manipulation
import pandas as pd
import numpy as np

# Options for pandas
pd.options.display.max_columns = 50
pd.options.display.max_rows = 100
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

from IPython import get_ipython
ipython = get_ipython()

# autoreload extension
if 'autoreload' not in ipython.extension_manager.loaded:
    # %load_ext autoreload

# %autoreload 2

# Ignore exceptions
import expectexception

# Visualizations
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# Activate the automatic conversion for pandas
from rpy2.robjects import pandas2ri
pandas2ri.activate()

# Load the needed extension for the %%R cell magic
# %load_ext rpy2.ipython

# Load ipywidgets module
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# %%R
#
# # load the r library
# library(ggplot2)
# library(ggalt)
# theme_set(theme_light())
#
# library(scales)
# library(dplyr)
# Out:
# /Users/nelson/anaconda3/lib/python3.7/site-packages/rpy2/rinterface/__init__.py:146: RRuntimeWarning:
#
#
# Attaching package: ‘dplyr’
#
#
#
# /Users/nelson/anaconda3/lib/python3.7/site-packages/rpy2/rinterface/__init__.py:146: RRuntimeWarning:
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#
# /Users/nelson/anaconda3/lib/python3.7/site-packages/rpy2/rinterface/__init__.py:146: RRuntimeWarning:
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
CLR = pd.read_csv('../clean_csv/CLR_clean.csv')

production = pd.read_csv('../clean_csv/production_clean.csv')

# %%
CLR = CLR[['doc_id', 'maturity', 'product_type', 'instrument_type', 'vol_1', 'vol_1_type']]

# %%
CLR['maturity'] = CLR['maturity'].apply(lambda x: int(str(x)[0:4]))

# %%
CLR
# Out:
#           doc_id  maturity product_type instrument_type      vol_1 vol_1_type
# 0    CLR20100226      2010          oil            swap        343      mbbls
# 1    CLR20100226      2010          oil          collar        148      mbbls
# 2    CLR20100226      2010          oil            swap        410      mbbls
# 3    CLR20100226      2010          oil          collar        228      mbbls
# 4    CLR20100226      2010          oil            swap        414      mbbls
# 5    CLR20100226      2010          oil          collar        598      mbbls
# 6    CLR20100226      2010          oil            swap        414      mbbls
# 7    CLR20100226      2010          oil          collar        598      mbbls
# 8    CLR20100226      2010          oil            swap        343      mbbls
# 9    CLR20100226      2010          oil          collar        148      mbbls
# 10   CLR20100226      2010          oil            swap        410      mbbls
# 11   CLR20100226      2010          oil          collar        228      mbbls
# 12   CLR20100226      2010          oil            swap        414      mbbls
# 13   CLR20100226      2010          oil          collar        598      mbbls
# 14   CLR20100226      2010          oil            swap        414      mbbls
# 15   CLR20100226      2010          oil          collar        598      mbbls
# 16   CLR20100226      2010  natural gas            swap        590     mmmbtu
# 17   CLR20100226      2010  natural gas            swap       3163     mmmbtu
# 18   CLR20100226      2011  natural gas            swap      11863     mmmbtu
# 19   CLR20100226      2010          oil            swap        905      mbbls
# 20   CLR20100226      2010          oil          collar        453      mbbls
# 21   CLR20100226      2010          oil          collar        644      mbbls
# 22   CLR20100226      2011          oil          collar       1278      mbbls
# 23   CLR20100226      2010          oil            swap        905      mbbls
# 24   CLR20100226      2010          oil          collar        453      mbbls
# 25   CLR20100226      2010          oil          collar        644      mbbls
# 26   CLR20100226      2011          oil          collar       1278      mbbls
# 27   CLR20100226      2010  natural gas            swap       2700     mmmbtu
# 28   CLR20100226      2010  natural gas            swap       2710     mmmbtu
# 29   CLR20100226      2010  natural gas            swap       2720     mmmbtu
# 30   CLR20100226      2010  natural gas            swap       2720     mmmbtu
# 31   CLR20100226      2010  natural gas            swap       7200     mmmbtu
# 32   CLR20110225      2012          oil            swap     915000       bbls
# 33   CLR20110225      2013          oil          collar    3102500       bbls
# 34   CLR20110225      2012          oil            swap     915000       bbls
# 35   CLR20110225      2013          oil          collar    3102500       bbls
# 36   CLR20110225      2011  natural gas            swap    2360000      mmbtu
# 37   CLR20110225      2011  natural gas            swap    3640000      mmbtu
# 38   CLR20110225      2011  natural gas            swap    3910000      mmbtu
# 39   CLR20110225      2011  natural gas            swap    4232000      mmbtu
# 40   CLR20110225      2012  natural gas            swap    3660000      mmbtu
# 41   CLR20110225      2011          oil            swap     284000       bbls
# 42   CLR20110225      2011          oil          collar    2565000       bbls
# 43   CLR20110225      2011          oil            swap     273000       bbls
# 44   CLR20110225      2011          oil          collar    2593500       bbls
# 45   CLR20110225      2011          oil            swap     460000       bbls
# 46   CLR20110225      2011          oil          collar    2622000       bbls
# 47   CLR20110225      2011          oil            swap     644000       bbls
# 48   CLR20110225      2011          oil          collar    2622000       bbls
# 49   CLR20110225      2012          oil            swap    7320000       bbls
# ..           ...       ...          ...             ...        ...        ...
# 78   CLR20120224      2013          oil          collar    8760000       bbls
# 79   CLR20120224      2012  natural gas            swap    3660000      mmbtu
# 80   CLR20130228      2013          oil            swap     270000       bbls
# 81   CLR20130228      2013          oil            swap    1100000       bbls
# 82   CLR20130228      2014          oil            swap    5292500       bbls
# 83   CLR20130228      2013  natural gas            swap   13360000      mmbtu
# 84   CLR20130228      2013          oil            swap   11862500       bbls
# 85   CLR20130228      2013          oil          collar    8760000       bbls
# 86   CLR20130228      2014          oil            swap   10311250       bbls
# 87   CLR20130228      2013          oil            swap   11862500       bbls
# 88   CLR20130228      2013          oil          collar    8760000       bbls
# 89   CLR20130228      2014          oil            swap   10311250       bbls
# 90   CLR20130228      2013          oil            swap    3467500       bbls
# 91   CLR20130228      2014          oil            swap    6570000       bbls
# 92   CLR20130228      2014          oil          collar    2190000       bbls
# 93   CLR20130228      2015          oil            swap    1277500       bbls
# 94   CLR20130228      2013          oil            swap    3467500       bbls
# 95   CLR20130228      2014          oil            swap    6570000       bbls
# 96   CLR20130228      2014          oil          collar    2190000       bbls
# 97   CLR20130228      2015          oil            swap    1277500       bbls
# 98   CLR20130228      2013  natural gas            swap   18250000      mmbtu
# 99   CLR20140227      2015          oil            swap    6205000       bbls
# 100  CLR20140227      2014  natural gas            swap   40495000      mmbtu
# 101  CLR20140227      2015  natural gas            swap   22700000      mmbtu
# 102  CLR20140227      2016  natural gas            swap    4550000      mmbtu
# 103  CLR20140227      2014          oil            swap   10851250       bbls
# 104  CLR20140227      2014          oil            swap   17028000       bbls
# 105  CLR20140227      2014          oil          collar    2190000       bbls
# 106  CLR20140227      2015          oil            swap    2737500       bbls
# 107  CLR20140227      2015          oil          collar     730000       bbls
# 108  CLR20140227      2014          oil            swap   17028000       bbls
# 109  CLR20140227      2014          oil          collar    2190000       bbls
# 110  CLR20140227      2015          oil            swap    2737500       bbls
# 111  CLR20140227      2015          oil          collar     730000       bbls
# 112  CLR20140227      2014  natural gas            swap   64250000      mmbtu
# 113  CLR20140227      2015  natural gas            swap    1800000      mmbtu
# 114  CLR20150224      2015          oil            call    2208000       bbls
# 115  CLR20150224      2015          oil            call     368000       bbls
# 116  CLR20150224      2016          oil            call    1464000       bbls
# 117  CLR20150224      2015  natural gas            swap   24500000      mmbtu
# 118  CLR20150224      2015  natural gas          collar   29200000      mmbtu
# 119  CLR20150224      2016  natural gas            swap   63110000      mmbtu
# 120  CLR20160224      2016          oil            call    1464000       bbls
# 121  CLR20160224      2016  natural gas            swap  133710000      mmbtu
# 122  CLR20160224      2017  natural gas            swap   25550000      mmbtu
# 123  CLR20160224      2017  natural gas          collar   65700000      mmbtu
# 124  CLR20170222      2017  natural gas            swap   49520000      mmbtu
# 125  CLR20170222      2018  natural gas            swap    6300000      mmbtu
# 126  CLR20170222      2017  natural gas            swap   72690000      mmbtu
# 127  CLR20170222      2017  natural gas          collar   65700000      mmbtu
#
# [128 rows x 6 columns]

# %%
import re

CLR['year'] = CLR['doc_id'].apply(lambda x: int(re.findall('\d{4}', x)[0]))

CLR['ticker'] = CLR['doc_id'].apply(lambda x: re.findall('[A-Z]+', x)[0])

CLR = CLR.loc[(CLR['maturity'] == CLR['year']) & (~CLR['instrument_type'].str.contains('basis'))].reset_index(drop=True)

# %%
unit_convertion = {
    'bcf': 25/9,
    'mbbls': 1/365,
    'bbls': 1/365000,
    'mmbtu': 1/370475,
    'mmmbtu': 40/14819
}

product_convertion = {
    'natural gas': 'Natural Gas',
    'oil': 'Oil',
    'natural gas (bcf)': 'Natural Gas'
}

# %%
CLR['multiplier'] = CLR['vol_1_type'].map(unit_convertion)
CLR['product'] = CLR['product_type'].map(product_convertion)
CLR['volume'] = CLR['vol_1'] * CLR['multiplier']

CLR = CLR[['ticker', 'year', 'product', 'volume', 'instrument_type']]

# %%
CLR = CLR.drop_duplicates()

CLR = CLR.drop('instrument_type', axis = 1)

# %%
CLR = CLR.groupby(['year', 'product']).agg({'volume':'sum', 'ticker':'first'}).reset_index()

# %%
CLR_merge = pd.merge(CLR, production, on=['year', 'ticker'])

# %%
CLR_merge['production'] = np.where(CLR_merge['product'] == 'Natural Gas', CLR_merge['GAS_PRODUCTION'], 
         np.where(CLR_merge['product'] == 'Oil', CLR_merge['OIL_PRODUCTION'], CLR_merge['NGL_PRODUCTION']))

CLR_merge['hedge_ratio'] = CLR_merge['volume'] / CLR_merge['production']

CLR_merge = CLR_merge[['ticker', 'year', 'product', 'volume', 'production', 'hedge_ratio']]

CLR_merge
# Out:
#    ticker  year      product  volume  production  hedge_ratio
# 0     CLR  2010  Natural Gas  51.510      65.600        0.785
# 1     CLR  2010          Oil  11.351      32.380        0.351
# 2     CLR  2011  Natural Gas  70.192     100.470        0.699
# 3     CLR  2011          Oil  25.867      45.120        0.573
# 4     CLR  2012  Natural Gas  23.888     174.521        0.137
# 5     CLR  2012          Oil  44.504      68.497        0.650
# 6     CLR  2013  Natural Gas  85.323     240.355        0.355
# 7     CLR  2013          Oil  69.753      95.859        0.728
# 8     CLR  2014  Natural Gas 282.732     313.137        0.903
# 9     CLR  2014          Oil  82.382     121.999        0.675
# 10    CLR  2015  Natural Gas 144.949     450.558        0.322
# 11    CLR  2015          Oil   7.058     146.622        0.048
# 12    CLR  2016  Natural Gas 360.915     533.442        0.677
# 13    CLR  2016          Oil   4.011     128.005        0.031
# 14    CLR  2017  Natural Gas 507.214     625.093        0.811

# %%
CLR_merge.to_csv('../hedge_ratio/CLR_hedge_ratio.csv', index=False)
